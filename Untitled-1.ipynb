# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
df = pd.read_csv("Diabetes_Final_Data_V2.csv")
df.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42  Female          66          110            73     5.88    1.65
# 1   35  Female          60          125            68     5.71    1.47
# 2   62  Female          57          127            74     6.85    1.52
# 3   73    Male          55          193           112     6.28    1.63
# 4   68  Female          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke diabetic
# 0                       0       0       No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5437 entries, 0 to 5436
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5437 non-null   int64
#  1   gender                  5437 non-null   object
#  2   pulse_rate              5437 non-null   int64
#  3   systolic_bp             5437 non-null   int64
#  4   diastolic_bp            5437 non-null   int64
#  5   glucose                 5437 non-null   float64
#  6   height                  5437 non-null   float64
#  7   weight                  5437 non-null   float64
#  8   bmi                     5437 non-null   float64
#  9   family_diabetes         5437 non-null   int64
#  10  hypertensive            5437 non-null   int64
#  11  family_hypertension     5437 non-null   int64
#  12  cardiovascular_disease  5437 non-null   int64
#  13  stroke                  5437 non-null   int64
# ...

# %%
df["gender"] = df["gender"].map({"Male": 1, "Female": 0})
df["diabetic"] = df["diabetic"].map({"Yes": 1, "No": 0})

df.head()
# Out:
#    age  gender  pulse_rate  systolic_bp  diastolic_bp  glucose  height  \
# 0   42       0          66          110            73     5.88    1.65
# 1   35       0          60          125            68     5.71    1.47
# 2   62       0          57          127            74     6.85    1.52
# 3   73       1          55          193           112     6.28    1.63
# 4   68       0          71          150            81     5.71    1.42
#
#    weight    bmi  family_diabetes  hypertensive  family_hypertension  \
# 0    70.2  25.75                0             0                    0
# 1    42.5  19.58                0             0                    0
# 2    47.0  20.24                0             0                    0
# 3    57.4  21.72                0             0                    0
# 4    36.0  17.79                0             0                    0
#
#    cardiovascular_disease  stroke  diabetic
# 0                       0       0         0
# ...

# %%
X = df.drop("diabetic", axis=1)
y = df["diabetic"]

print(X.shape)
print(y.shape)
# Out:
# (5437, 14)
# (5437,)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

# %%
model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)

print("Akurasi:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Akurasi: 0.9420955882352942
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1024
#            1       0.53      0.12      0.20        64
#
#     accuracy                           0.94      1088
#    macro avg       0.74      0.56      0.59      1088
# weighted avg       0.92      0.94      0.92      1088
#
# Confusion Matrix:
#  [[1017    7]
#  [  56    8]]

# %%
data_baru = [[
    45, 1, 72, 130, 85, 145,
    170, 75, 26,
    1, 1, 0, 0, 0
]]

data_baru = scaler.transform(data_baru)
hasil = model.predict(data_baru)

print("HASIL:", "DIABETES" if hasil[0] == 1 else "TIDAK DIABETES")
# Out:
# HASIL: DIABETES
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="diabetic", data=df)
plt.title("Distribusi Pasien Diabetes")
plt.xlabel("Status Diabetes (0 = Tidak, 1 = Ya)")
plt.ylabel("Jumlah Pasien")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="age", hue="diabetic", bins=30, kde=True)
plt.title("Distribusi Umur Pasien Terhadap Diabetes")
plt.xlabel("Umur")
plt.ylabel("Frekuensi")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x="diabetic", y="bmi", data=df)
plt.title("Perbandingan BMI Berdasarkan Status Diabetes")
plt.xlabel("Status Diabetes (0 = Tidak, 1 = Ya)")
plt.ylabel("BMI")
plt.show()

# %% [markdown]
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
# plt.title("Heatmap Korelasi Fitur")
# plt.show()
